# %%
name="kowsalya"
age=24
location="Neyveli"
email="mkowsalya098@gmail.com"
working=True
course="py,ml"
percentage=78.3
sports="football"
food="lemon rice"
salary=10000
company="BuSoft Tech"
Education="M.Sc Maths"


print(f"I am {name} and my age is {age}")
print(f"my hometown is {location}")
print(f"are u working {working}")
print(f"i have completed a course on {course}")
print(f"I have scored the {percentage} in M.sc")
print(f"my fav sports is {sports}")
print(f"My personal email is {email}")
print(f"i have completed {Education} in Sastra university")
print(f"Now i am currently working in {company}")
print(f"my current salary is {salary}")


print("-------------------------------------------------------------------------")


print("my name  is {} and my age is {}".format(name,age))
print("I am currently working at {} with {} stripend".format(company,salary))

print("-------------------------------------------------------------------------")

print(f"name:{name}\nage:{age}\nlocation:{location}\nemail:{email}\nworking:{working}\ncourse:{course}\npercentage:{percentage}\nsports:{sports}\nfood:{food}\nsalary:{salary}\ncompany:{company}\nEducation:{Education}")


print("-------------------------------------------------------------------------")

print(f"name:{name}\tage:{age}\tlocation:{location}\temail:{email}\tworking:{working}\tcourse:{course}\tpercentage:{percentage}\tsports:{sports}\tfood:{food}\tsalary:{salary}\tcompany:{company}\tEducation:{Education}")
# Out:
# I am kowsalya and my age is 24
# my hometown is Neyveli
# are u working True
# i have completed a course on py,ml
# I have scored the 78.3 in M.sc
# my fav sports is football
# My personal email is mkowsalya098@gmail.com
# i have completed M.Sc Maths in Sastra university
# Now i am currently working in BuSoft Tech
# my current salary is 10000
# -------------------------------------------------------------------------
# my name  is kowsalya and my age is 24
# I am currently working at BuSoft Tech with 10000 stripend
# -------------------------------------------------------------------------
# name:kowsalya
# age:24
# location:Neyveli
# email:mkowsalya098@gmail.com
# working:True
# course:py,ml
# percentage:78.3
# sports:football
# food:lemon rice
# salary:10000
# company:BuSoft Tech
# Education:M.Sc Maths
# -------------------------------------------------------------------------
# ...

# %%
Age=10
age=10
AGE=10
_age=10
__age=10
True=10
6kowsy=10
kowsy$=10

# %%
salary_kows=10_000
print("salary_kows",salary_kows)
# Out:
# salary_kows 10000

# %%
class_room=40
classRoomPeople=10
ClassRoomPeople=12

# %%
import keyword
keys=keyword.kwlist
print(keys)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keys)
# Out:
# 35

# %%
help(False)
# Out:
# Help on bool object:
#
# class bool(int)
#  |  bool(x) -> bool
#  |
#  |  Returns True when the argument x is true, False otherwise.
#  |  The builtins True and False are the only two instances of the class bool.
#  |  The class bool is a subclass of the class int, and cannot be subclassed.
#  |
#  |  Method resolution order:
#  |      bool
#  |      int
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __invert__(self, /)
#  |      ~self
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  ----------------------------------------------------------------------
# ...

# %%
help(lambda)
# Out:
#   Cell In[26], line 1
#     help(lambda)
#                ^
# SyntaxError: invalid syntax

# %%
help(if)
# Out:
#   Cell In[27], line 1
#     help(if)
#          ^
# SyntaxError: invalid syntax

# %%
help()
# Out:
# Welcome to Python 3.12's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the internet at https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# The "with" statement
# ********************
#
# The "with" statement is used to wrap the execution of a block with
# methods defined by a context manager (see section With Statement
# Context Managers). This allows common "try"…"except"…"finally" usage
# patterns to be encapsulated for convenient reuse.
#
# ...

# %%
a=int(input("Enter the value 1"))
b=int(input("Enter the value 2"))
if a>b:
    print("a is greater than b")
elif a<b:
    print("a is less than b")
else:
    print("a is equal to b")
# Out:
# a is greater than b

# %%
def hello():
    ''' hello guys'''
    return "good morning"
hello()
# Out:
# 'good morning'

# %%
help(hello)
# Out:
# Help on function hello in module __main__:
#
# hello()
#     hello guys

# %%
a=input("Enter the value 1")
b=input("Enter the value 2")
if (a==b):
    print("both the name is same")
else:
    print("name is different")
# Out:
# both the name is same

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
print(math.factorial(10))
print(math.pow(3,2))

print(math.remainder(10,2))
print(math.ceil(4.678))
print(math.floor(4.678))
a=200
print(a*math.pi)
# Out:
# 3628800
# 9.0
# 0.0
# 5
# 4
# 628.3185307179587

# %%
from math import *

# %%
trunc(4.5)
# Out:
# 4

# %%
fabs(-2.8)
# Out:
# 2.8

# %%
help(fabs)
# Out:
# Help on built-in function fabs in module math:
#
# fabs(x, /)
#     Return the absolute value of the float x.

# %%
help(nan)
# Out:
# Help on float object:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(self, /)
#  |      Return the ceiling as an Integral.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(self, /)
#  |      Return the floor as an Integral.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
# ...
